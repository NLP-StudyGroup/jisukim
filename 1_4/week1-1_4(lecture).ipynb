# %% [markdown]
# ## 데이터 정제 실습 1
#
# ### 활용 데이터: sample.csv
#
# ### 실습 개요
# 이 실습에서는 Google Colab에 CSV 파일을 마운트 하고, Pandas 라이브러리를 사용하여 파일을 읽은 다음, 특정 컬럼의 데이터를 분석합니다. 구체적으로, 'en'과 'ko' 라는 두 개의 컬럼에 대해 각각 띄어쓰기로 분할하여 단어의 수를 세고, 이 정보를 새로운 컬럼에 저장합니다.
#
#
# ### 실습 절차
# 1. CSV 파일 마운트: Google Colab에 CSV 파일을 업로드합니다.
# 2. 데이터 읽기: Pandas를 사용하여 CSV 파일을 읽고 DataFrame으로 변환합니다.
# 3. 데이터 처리:
# - 'en'과 'ko' 컬럼의 데이터를 띄어쓰기 단위로 분할합니다.
# - 각 행에 대해 영어와 한국어 단어의 개수를 세고, 이를 새로운 컬럼에 저장합니다.
# 4. en 칼럼에 대해 길이가 긴 순서대로 DataFrame을 재 정렬합니다.
# 5. 해당 DataFrame을 csv형식으로 저장합니다.

# %%
## 실습 할 텍스트 구글 드라이브에 import
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/drive/MyDrive/NLP정답/1-4/sample.csv")

# %%
data.head(2)
# Out:
#                                                   en  \
# 0  Among the suppressor mutants, NAFM733 produced...
# 1  The concentrations of total alkalinity, total ...
#
#                                                   ko
# 0  억제 돌연변이 중 NAFM733은 0.1mg/ml로 γPGA를 생성했는데, 이는 다...
# 1  총 알칼리도, 총 암모늄, tVFA와 pH의 농도는 모넨신 사료를 투여한 젖소의 거...

# %%
data['en_count'] = data['en'].apply(lambda x: len(x.split()))
data['ko_count'] = data['ko'].apply(lambda x: len(x.split()))

# %%
data.head(2)
# Out:
#                                                   en  \
# 0  Among the suppressor mutants, NAFM733 produced...
# 1  The concentrations of total alkalinity, total ...
#
#                                                   ko  en_count  ko_count
# 0  억제 돌연변이 중 NAFM733은 0.1mg/ml로 γPGA를 생성했는데, 이는 다...        21        15
# 1  총 알칼리도, 총 암모늄, tVFA와 pH의 농도는 모넨신 사료를 투여한 젖소의 거...        23        13

# %%
data = data.sort_values(by='en_count', ascending=False)

# %%
data
# Out:
#                                                     en  \
# 54   To date, nine distinct van gene clusters have ...
# 24   Solutions containing up to 0.5% acetic acid, c...
# 73   To investigate the distribution of IS1380 in o...
# 27   This increase in travel time and distance make...
# 22   About 500,000 tons in excess rice, which were ...
# ..                                                 ...
# 114  YM-53601 inhibits de novo synthesis of cholest...
# 81   Immune sera were collected from mice at wk 2 p...
# 76   The developed method was validated using spike...
# 96   They were seen less frequently than the gram-p...
# 100  There are several challenges that need closer ...
#
#                                                     ko  en_count  ko_count
# 54   현재까지 9개의 별개의 van 유전자 군집이 분류되었으며 인간 VRE 감염의 대부분...        44        28
# 24   젖산 0.1% 뿐 아니라, 아세트산, 시트르산, 나트륨 프로피온산염 또는 칼륨 소르...        42        32
# 73   다른 아세트산 박테리아에서 IS1380의 분포를 조사하기 위해 1S1380의 1.1...        39        26
# 27   이러한 이동 시간과 거리의 증가는 APHIS가 28시간 규칙과 같은 운송 규정을 효...        38        26
# 22   2005~2008년 사이에 수확한 쌀 50만t을 저장고에 넣어 2011년 말까지 저...        37        16
# ..                                                 ...       ...       ...
# 114         YM-53601은 콜레스테롤과 콜레스테롤 에스테르의 새로운 합성을 억제한다.        10         7
# 81                   면역 혈청은 부스팅 후 2주째에 마우스로부터 수집되었습니다.        10         7
# 76                  개발된 방법은 스파이크 즉석 식품 샘플을 사용하여 검증하였다.        10         8
# 96                           그들은 그람양성 유기체보다 덜 자주 나타났다.         9         6
# 100                           세심한 주의가 필요한 몇 가지 과제가 있다.         8         7
#
# [120 rows x 4 columns]

# %%
data.to_csv('result1.csv', index=False)

# %%
data.to_csv('/content/drive/MyDrive/NLP정답/1-4/result1.csv', index=False) ## 경로 지정 후 저장
# 엑셀로 저장하고 싶을 경우: data.to_excel('이름.xlsx')
